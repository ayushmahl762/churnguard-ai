# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 33
#       1 {
#       2  "cells": [
#       3   {
#       4    "cell_type": "markdown",
#       5    "id": "1",
#       6    "metadata": {},
#       7    "source": [
#       8     "# ChurnGuard AI — ML Pipeline & Strategy\n",
#       9     "### Predictive modeling, feature rationale, and retention prioritization.\n",
#      10     "\n",
#      11     "---\n",
#      12     "\n",
#      13     "## Table of Contents\n",
#      14     "1. [Data Load & Feature Matrix](#1)\n",
#      15     "2. [Model Selection Rationale](#2)\n",
#      16     "3. [Model Comparison & Performance](#3)\n",
#      17     "4. [Threshold Optimisation (F2.0)](#4)\n",
#      18     "5. [SHAP Explainability](#5)\n",
#      19     "6. [Actionable Retention List](#6)\n"
#      20    ]
#      21   },
#      22   {
# ...
